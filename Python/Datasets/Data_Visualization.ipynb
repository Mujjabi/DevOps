# %% [markdown]
# ## Data Visualization
# We will use python and the library matplotlib to conduct some data visualization.
#
# We will also use a library Pandas used for data manipulation and analysis.

# %%
import pandas as pd

# %% [markdown]
# Import another library called pyplot

# %%
from matplotlib import pyplot as plt

# %%
All2023 = pd.read_csv("All2023.csv")
All2023
# Out:
#      Unnamed: 0  PlotID             Experiment  Year  Field. Rotation  Rep  \
# 0             1   10701  2023_Rotational Plots  2023     107    4Year    1
# 1             2   10702  2023_Rotational Plots  2023     107    4Year    1
# 2             3   10703  2023_Rotational Plots  2023     107    4Year    1
# 3             4   10704  2023_Rotational Plots  2023     107    4Year    1
# 4             5   10705  2023_Rotational Plots  2023     107    4Year    1
# ..          ...     ...                    ...   ...     ...      ...  ...
# 263         264   41511  2023_Rotational Plots  2023     415    4Year    4
# 264         265   41512  2023_Rotational Plots  2023     415    4Year    4
# 265         266   41513  2023_Rotational Plots  2023     415    4Year    4
# 266         267   41514  2023_Rotational Plots  2023     415    4Year    4
# 267         268   41515  2023_Rotational Plots  2023     415    4Year    4
#
#     N.Old Nitro         Pedigree  ...    LA_Mean      LA_SD   RTA_Mean  \
# 0      N3    N3           PH6878  ...  49.255723   4.641708  55.103364
# 1      N3    N3           PH5141  ...  45.517652  11.258438  53.835731
# 2      N3    N3        B73xPH207  ...  58.718838   6.796298  60.150504
# 3      N3    N3        B73xPHG47  ...  51.468145   6.378418  52.675328
# 4      N3    N3  Z031E0021xPHG47  ...  51.762901   7.166426  53.322538
# ..    ...   ...              ...  ...        ...        ...        ...
# 263    N3    N3  Z031E0021xPHG47  ...  54.894654  13.075044  56.989127
# 264    N3    N3           PH5141  ...  47.274008  13.406018  48.339212
# 265    N3    N3  Z031E0021xPHZ51  ...  40.537013  10.332765  38.957455
# 266    N3    N3          BR64K93  ...  58.445895  10.588180  57.678067
# 267    N3    N3   Z031E0021xMo17  ...  55.947409  11.171359  53.826460
#
#         RTA_SD     SD_Mean      SD_SD  LDA_Mean    LDA_SD    RTW_Mean  \
# 0     5.543384   79.750000   5.175492 -0.756637  3.530169  118.000000
# 1    12.422505  102.000000   9.638936 -0.827221  2.909513  209.000000
# 2     6.513391  113.750000  36.402110 -0.600538  2.543754  188.666667
# 3    10.892764   97.333333   7.643575 -0.768603  1.904535  193.333333
# 4     8.521522   89.083333   6.707639 -0.516319  3.115056  153.666667
# ..         ...         ...        ...       ...       ...         ...
# 263  12.770704  122.166667  26.994388 -0.562302  2.635000  178.333333
# 264  13.343399  106.583333   7.464563 -0.373850  3.155706  188.666667
# 265   7.290702  131.750000  44.255714 -0.127014  2.601941  240.000000
# 266   9.644018  108.916667  13.734220 -0.251129  2.911881  209.666667
# 267  10.590854  122.916667  13.872526 -0.234275  2.655091  177.000000
#
#         RTW_SD
# 0    12.828540
# 1    34.546411
# 2    65.484673
# 3    30.538600
# 4    30.633711
# ..         ...
# 263  47.865975
# 264  62.355773
# 265  67.371426
# 266  29.693383
# 267  34.016039
#
# [268 rows x 31 columns]

# %%
plt.plot(All2023.Rotation, All2023.FDT_Mean)
plt.plot(All2023.Rotation, All2023.FDS_Mean)
