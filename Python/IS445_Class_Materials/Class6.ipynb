# %%
import pandas as pd
from vega import VegaLite
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\mujjabi2\OneDrive - University of Illinois - Urbana\DevOps_Course\Remote_Repositories\AWS_Server_Repo\DevOps\Python\IS445_Class_Materials\Class6.ipynb Cell 1 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/mujjabi2/OneDrive%20-%20University%20of%20Illinois%20-%20Urbana/DevOps_Course/Remote_Repositories/AWS_Server_Repo/DevOps/Python/IS445_Class_Materials/Class6.ipynb#W0sZmlsZQ%3D%3D?line=0'>1</a> import pandas as pd
# ----> <a href='vscode-notebook-cell:/c%3A/Users/mujjabi2/OneDrive%20-%20University%20of%20Illinois%20-%20Urbana/DevOps_Course/Remote_Repositories/AWS_Server_Repo/DevOps/Python/IS445_Class_Materials/Class6.ipynb#W0sZmlsZQ%3D%3D?line=1'>2</a> from vega import VegaLite
#
# ModuleNotFoundError: No module named 'vega'
