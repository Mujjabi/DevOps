# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
np.linspace(0,4.0 * np.pi, 10)
# Out:
# array([ 0.        ,  1.3962634 ,  2.7925268 ,  4.1887902 ,  5.58505361,
#         6.98131701,  8.37758041,  9.77384381, 11.17010721, 12.56637061])

# %%
x = np.mgrid[0.0 : 4 *np.pi :10j]

# %%
Y1 = np.sin(x)
Y2 = np.cos(x)

# %%
plt
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\mujjabi2\\AppData\\Local\\anaconda3\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
x = np.mgrid[0.0 : 4 *np.pi :10j]

# %%
Y1 = np.sin(x)
Y2 = np.cos(x)

# %%
fig,ax = plt.subplots()
lines1 = ax.plot(x, Y1)
lines2 = ax.plot(x, Y2)

# %%
sin_line = lines1[0]
cos_line = lines2[0]

# %%
sin_line.set_marker
sin_line.set_color("red")
sin_line.set_linewidth(2.0)
sin_line.set_linestyle()
fig

# %%
fig, ax = plt.subplots()
x = np.random.normal(size = 100)
y = np.random.normal(size = 100)
sc = ax.scatter(x,y, marker = "o")

# %%
fig, ax = plt.subplots()
x = np.random.normal(size = 100)
y = np.random.normal(size = 100)
sc = ax.scatter(x,y, marker = "o")
ax.text (0.95, 0.95, "Hello")
# Out:
# Text(0.95, 0.95, 'Hello')

# %%
fig, ax = plt.subplots()
x = np.random.normal(size = 100)
y = np.random.normal(size = 100)
sc = ax.scatter(x,y, marker = "o")
ax.text (0.95, 0.95, "Hello", transform = ax.transAxes)
# Out:
# Text(0.95, 0.95, 'Hello')

# %%
fig, ax = plt.subplots()
x = np.random.normal(size = 100)
y = np.random.normal(size = 100)
sc = ax.scatter(x,y, marker = "o")
ax.text (0.95, 0.95, "Hello", transform = ax.transAxes, horizontalalignment="right", verticalalignment="top")
# Out:
# Text(0.95, 0.95, 'Hello')

# %%
fig, ax = plt.subplots(1, 2)

# %%
df = pd.read_csv("classes/fall2023-acg-acu/data/building_inventory.csv",
                 na_values = {'Year Acquired' : 0,
                              'Year Constructed' : 0,
                              'Square Footage' : 0}
                )
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 df = pd.read_csv("classes/fall2023-acg-acu/data/building_inventory.csv",
#       2                  na_values = {'Year Acquired' : 0,
#       3                               'Year Constructed' : 0,
#       4                               'Square Footage' : 0}
#       5                 )
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
# ...
